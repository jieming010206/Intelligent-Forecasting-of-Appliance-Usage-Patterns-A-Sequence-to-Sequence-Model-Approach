# %% [markdown]
# # inport package

# %%
# !pip install dill
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/household_2
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/household_appliance

# %%
import warnings
warnings.filterwarnings("ignore")
import logging
logging.getLogger('matplotlib.font_manager').disabled = True

# %%
# %run pretreatment.py
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py", line 714, in run
#     filename = file_finder(fpath)
#   File "/usr/local/lib/python3.10/dist-packages/IPython/utils/path.py", line 109, in get_py_filename
#     raise IOError('File `%r` not found.' % name)
# OSError: File `'pretreatment.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %% [markdown]
# # main

# %%
# %run main.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# /content/drive/MyDrive/household_appliance/outputs/base/appliance_evaluate.txt saving...
# /content/drive/MyDrive/household_appliance/outputs/base/duration_evaluate.txt saving...
# ---------------------------------------------
# edit_distance: 9.0913
# hamming_distance: 9.2772
# lcs: 4.2467
# best current val acc: 0.2269
# best current val loss: 24.2872
# ---------------------------------------------
#
#
# 100%|██████████| 65/65 [00:36<00:00,  1.80it/s]
# [train] Epoch: 300 / 1000, acc: 0.5961, loss: 2.0232
# 100%|██████████| 16/16 [00:02<00:00,  6.45it/s]
# [Eval] Epoch: 300 / 1000, acc: 0.2276, loss: 24.4316
# /content/drive/MyDrive/household_appliance/outputs/base/time_evaluate.txt saving...
# /content/drive/MyDrive/household_appliance/outputs/base/appliance_evaluate.txt saving...
# /content/drive/MyDrive/household_appliance/outputs/base/duration_evaluate.txt saving...
# ---------------------------------------------
# edit_distance: 9.0736
# ...
